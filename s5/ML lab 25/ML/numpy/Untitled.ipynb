# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
matrix=np.array([[1,2,3],[4,6,8]])

# %%
matrix
# Out:
# array([[1, 2, 3],
#        [4, 6, 8]])
