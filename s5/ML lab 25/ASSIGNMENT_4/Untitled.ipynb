# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
data=load_iris()

# %%
x=data.data
y=data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1234)

# %%
dt=DecisionTreeClassifier(criterion='gini')

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 1.0

# %%
print(f"accuracy={100*accuracy:.2f}")
# Out:
# accuracy=100.00

# %%
plt.figure(figsize=(12,8))

# %%
plot_tree(dt,feature_names=data.feature_names,class_names=data.target_names,filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'petal length (cm) <= 2.45\ngini = 0.666\nsamples = 120\nvalue = [41, 37, 42]\nclass = virginica'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]\nclass = setosa'),
#  Text(0.5769230769230769, 0.75, 'petal width (cm) <= 1.75\ngini = 0.498\nsamples = 79\nvalue = [0.0, 37.0, 42.0]\nclass = virginica'),
#  Text(0.3076923076923077, 0.5833333333333334, 'petal length (cm) <= 4.95\ngini = 0.214\nsamples = 41\nvalue = [0, 36, 5]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'petal width (cm) <= 1.65\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
# ...

# %%
rf=RandomForestClassifier(n_estimators=100,max_depth=3,random_state=42)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, random_state=42)

# %%
y_p=rf.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_p)

# %%
accuracy
# Out:
# 1.0

# %%
feature_importance=rf.feature_importances_

# %%
feature=data.feature_names

# %%
feature
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
feature_importance
# Out:
# array([0.10675335, 0.01182598, 0.42958381, 0.45183686])

# %%
importance_df=pd.DataFrame({'Feature':feature,'Importance_feature':feature_importance})

# %%
importance_df
# Out:
#              Feature  Importance_feature
# 0  sepal length (cm)            0.106753
# 1   sepal width (cm)            0.011826
# 2  petal length (cm)            0.429584
# 3   petal width (cm)            0.451837

# %%
importance_df.sort_values(by='Importance_feature',ascending=False)
# Out:
#              Feature  Importance_feature
# 3   petal width (cm)            0.451837
# 2  petal length (cm)            0.429584
# 0  sepal length (cm)            0.106753
# 1   sepal width (cm)            0.011826
