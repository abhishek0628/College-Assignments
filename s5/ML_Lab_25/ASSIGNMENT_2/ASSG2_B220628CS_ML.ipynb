# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# df=pd.read_csv("Iris.csv")
df=pd.read_csv("Iris.csv")

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# x=df.iloc[:,:-1]
# y=df.iloc[:,-1].values
x=df.iloc[:,:-1]
y=df.iloc[:,-1].values

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
# y.value_counts().plot(kind='bar')

# %%
for i in range(len(y)):
    if y[i]=="Iris-virginica":
       y[i]='0'
    else:
        y[i]='1'

# %%
y=pd.DataFrame(y)

# %%
x_train,x_test,y_train_y_test=train_test_split(x,y,test_size=0.2,random_state=1234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x_train,x_test,y_train_y_test=train_test_split(x,y,test_size=0.2,random_state=1234)
#
# ValueError: too many values to unpack (expected 3)

# %%
model=LogisticRegression()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("Iris.csv")

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1].values

# %%
ydf=pd.DataFrame(y)
ydf.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='0'>

# %%
for i in range(len(y)):
    if y[i]=="Iris-virginica":
       y[i]='0'
    else:
        y[i]='1'

# %%
X_train,X_test,y_train,x_test=train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
def compute_cost(X, y, theta):
    m = len(y)
    
    z = np.dot(X, theta)
    h = sigmoid(z)
    
    # Avoid log(0) disaster
    epsilon = 1e-5
    h = np.clip(h, epsilon, 1 - epsilon)
    
    cost = -(1/m) * np.sum(
        y * np.log(h) + (1 - y) * np.log(1 - h)
    )
    
    return cost

# %%
def gradient_descent(X, y, theta, lr, iterations):
    m = len(y)
    costs = []
    
    for i in range(iterations):
        z = np.dot(X, theta)
        h = sigmoid(z)
        
        gradient = (1/m) * np.dot(X.T, (h - y))
        
        theta -= lr * gradient
        
        cost = compute_cost(X, y, theta)
        costs.append(cost)
    
    return theta, costs

# %%
# Add bias term
X = np.c_[np.ones(X.shape[0]), X]

theta = np.zeros(X.shape[1])

theta, costs = gradient_descent(X, y, theta, lr=0.01, iterations=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 6
#       2 X = np.c_[np.ones(X.shape[0]), X]
#       4 theta = np.zeros(X.shape[1])
# ----> 6 theta, costs = gradient_descent(X, y, theta, lr=0.01, iterations=1000)
#
# Cell In[72], line 9, in gradient_descent(X, y, theta, lr, iterations)
#       6 z = np.dot(X, theta)
#       7 h = sigmoid(z)
# ----> 9 gradient = (1/m) * np.dot(X.T, (h - y))
#      11 theta -= lr * gradient
#      13 cost = compute_cost(X, y, theta)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %%
plt.plot(costs)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Cost Function Convergence")
plt.show()

# %%
import pandas as pd
pd.Series([[1,2,3,4],[3,4,5,6]])
# Out:
# 0    [1, 2, 3, 4]
# 1    [3, 4, 5, 6]
# dtype: object
